# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import json
import re
import datetime

# %% [markdown]
# ### Scraping MKW.hk
# #### One period-only

# %%
URL = "http://www.mkw.hk/"
html = requests.get(URL)
URL_source_code=html.text

# %%
print(html)
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(URL_source_code,"html.parser")
soup
# Out:
# ﻿<!DOCTYPE html>
#
# <!--[if IE]><![endif]-->
# <!--[if IE 8 ]><html dir="ltr" lang="en" class="ie8"><![endif]-->
# <!--[if IE 9 ]><html dir="ltr" lang="en" class="ie9"><![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!-->
# <html dir="ltr" lang="en">
# <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <title>旺角二手機網-全港最高回收價</title>
# <base href="http://mkw.hk/"/>
# <meta content="旺角二手機網" name="description"/>
# <meta content="手機回收價  iphone回收價  手機回收 iphone13回收價  iPhone 11pro/max回收價  iphone xs 回收價 iphone8回收價  iphone x回收 Samsung回收價 二手電話回收價   iphone12回收價   手機回收站 二手手機回收價 手機trade in 舊手機回收價  LG 華為 sony   先達手機回收 全新手機回收價  iPhone12/12pro /max回收價 iPad回收價 iPhone12回收二手" name="keywords"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="http://mkw.hk/image/catalog/new/MK.jpg" rel="icon"/>
# <script src="catalog/view/javascript/jquery/jquery-2.1.1.min.js" type="text/javascript"></script>
# <link href="catalog/view/javascript/bootstrap/css/bootstrap.min.css" media="screen" rel="stylesheet"/>
# <script src="catalog/view/javascript/bootstrap/js/bootstrap.min.js" type="text/javascript"></script>
# <link href="catalog/view/javascript/font-awesome/css/font-awesome.min.css" rel="stylesheet" type="text/css"/>
# <!-- Google Fonts -->
# <link href="https://fonts.googleapis.com/css?family=Lato:400,900,700" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Raleway:400,500,600,700,900,800,300" rel="stylesheet" type="text/css"/>
# <link href="//fonts.googleapis.com/css?family=Open+Sans:400,400i,300,700" rel="stylesheet" type="text/css">
# <link href="catalog/view/theme/micrablue/stylesheet/stylesheet.css" rel="stylesheet"/>
# <link href="catalog/view/theme/micrablue/stylesheet/font-awesome.css" rel="stylesheet"/>
# <link href="catalog/view/theme/micrablue/stylesheet/animate.css" rel="stylesheet"/>
# <link href="catalog/view/theme/micrablue/stylesheet/jquery.mobile-menu.css" rel="stylesheet" type="text/css"/>
# <link href="catalog/view/theme/micrablue/stylesheet/style.css" rel="stylesheet"/>
# <style type="text/css">
#
# /* sale label */
# .sale-label {background:#da2c2a}
#
# /*Main color section */
#
#
# /* header color section */
#
#
# /*Top Menu */
# /*background*/
# /*main menu links*/
# /*main menu link hover*/
# /*sub links hover*/
#
#
# /*buttons*/
#
#
# /*price*/
#
# /*footer*/
#
# </style>
# <link href="catalog/view/theme/micrablue/stylesheet/revslider.css" media="screen" rel="stylesheet" type="text/css">
# <link href="catalog/view/theme/micrablue/stylesheet/full-slider.css" media="screen" rel="stylesheet" type="text/css">
# <!-- <script src="catalog/view/javascript/common.js" type="text/javascript"></script> -->
# <script src="catalog/view/theme/micrablue/js/parallax.js" type="text/javascript"></script>
# <script src="catalog/view/theme/micrablue/js/common.js" type="text/javascript"></script>
# <script src="catalog/view/theme/micrablue/js/common1.js" type="text/javascript"></script>
# <script src="catalog/view/javascript/jquery/owl-carousel/owl.carousel.min.js" type="text/javascript"></script>
# <script src="catalog/view/theme/micrablue/js/jquery.mobile-menu.min.js" type="text/javascript"></script>
# <link href="catalog/view/theme/micrablue/js/fancybox/jquery.fancybox.css" rel="stylesheet"/>
# <script src="catalog/view/theme/micrablue/js/fancybox/jquery.fancybox.js" type="text/javascript"></script>
# <script src="catalog/view/theme/micrablue/js/revslider.js" type="text/javascript"></script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-103013910-1', 'auto');
#   ga('send', 'pageview');
#
# </script>手機回收價 手機回收 iphone回收價 手機回收報價 回收手機 二手回收價 先達手機回收
# </link></link></link></head>
# <body class="common-home">
# <div id="page">
# <header class="header-container">
# <div class="header-top">
# <div class="container">
# <div class="row">
# <div class="col-lg-6 col-md-4 col-sm-3 col-xs-12">
# <div class="phone hidden-xs">
# <div class="phone-box"><strong>Call:</strong> <span>+852 59139457‬</span></div>
# </div>
# <div class="welcome-msg hidden-xs">Welcome visitor!</div>
# </div>
# <div class="col-lg-6 col-md-8 col-sm-9 col-xs-12">
# <div class="top-cart-contain">
# <div class="mini-cart">
# <div id="cart">
# <div class="header basket dropdown-toggle">
# <a href="http://mkw.hk/index.php?route=checkout/cart"><i class="icon-cart"></i> <span class="before-cart-total cart-box"><span id="cart-total">0</span></span></a>
# </div>
# <ul class="dropdown-menu pull-right top-cart-content arrow_box">
# <li>
# <p class="text-center">您的購物車沒有添加商品！</p>
# </li>
# </ul>
# </div>
# </div>
# </div><!-- top-cart-contain -->
# <!-- <div class="collapse navbar-collapse">
#               <div class="navbar-form" role="search">
#                 <div class="input-group">
#                   <input type="text" class="form-control b" placeholder="Search" name="search">
#                   <span class="input-group-btn">
#                   <button type="reset" class="btn btn-default a"> <span class="glyphicon glyphicon-remove"> <span class="sr-only">Close</span> </span> </button>
#                   <button type="text" class="btn btn-default"> <span class="glyphicon glyphicon-search"> <span class="sr-only">Search</span> </span> </button>
#                   </span> </div>
#               </div>
#             </div> -->
# <div class="search-bar" id="form-search">
# <div id="search_mini_form">
# <input autocomplete="off" class="search-bar-input" maxlength="128" name="search" placeholder="搜索" type="text" value="women"/>
# <div class="search-icon a" title="Search"><span></span></div>
# <button class="search-icon b" style="display:none" title="Search"><span></span></button>
# </div>
# </div>
# <script type="text/javascript">
#             new UISearch(document.getElementById('form-search'));
# </script>
# <script>
# $('.search-bar .a').click(function() {
# //$('#form-search').attr('class','search-bar search-bar-open');
# $('#form-search .a').hide();
# $('#form-search .b').show();
# });
# </script>
# <script>
# // jQuery(document).ready(function(){
# // $('.glyphicon-search').click(function() {
# // $('.navbar-form').attr('class','navbar-form active');
# //$('#form-search .a').hide();
# //$('#form-search .b').show();
# // });
# // });
# </script>
# <!-- <div id="form-search" class="search-bar">
#    <a  id="search_mini_form">
#         <input type="text" maxlength="128" value="" placeholder="" name="search" class="search-bar-input" autocomplete="off">
#         <div class="search-icon a" title="Search"><span></span></div>
#         <button class="search-icon b" title="Search" style="display:none"><span></span></button>
#   </a>
#  </div> -->
# <script>
# // $('.search-bar .a').click(function() {
# // //$('#form-search').attr('class','search-bar search-bar-open');
# // $('#form-search .a').hide();
# // $('#form-search .b').show();
# // });
# </script>
# <div class="toplinks">
# <div class="links">
# <div class="login">
# <a href="http://mkw.hk/index.php?route=account/login" title="登錄"><span class="hidden-xs">登錄</span></a>
# </div>
# <div class="wishlist"><a href="http://mkw.hk/index.php?route=account/wishlist" title="0"><span class="hidden-xs"><i class="icon-star"> </i><span class="wishlist-items" id="wishlist-total">0</span></span></a>
# </div>
# </div>
# </div><!-- toplinks -->
# <div class="dropdown block-language-wrapper">
# <form action="http://mkw.hk/index.php?route=common/language/language" enctype="multipart/form-data" id="language" method="post">
# <div class="block-language dropdown-toggle" data-toggle="dropdown">
# <img alt="TCH" src="image/flags/hk.png" title="TCH"/>
#     TC    <span class="caret"></span>
# </div>
# <ul class="dropdown-menu">
# <li><a href="zh_HK"><img alt="TCH" src="image/flags/hk.png" title="TCH"> TCH</img></a></li>
# <li><a href="en"><img alt="English" src="image/flags/gb.png" title="English"/> English</a></li>
# </ul>
# <input name="code" type="hidden" value="">
# <input name="redirect" type="hidden" value="http://mkw.hk/index.php?route=common/home"/>
# </input></form>
# </div><!-- dropdown block-language-wrapper -->
# <div class="dropdown block-currency-wrapper">
# <form action="http://mkw.hk/index.php?route=common/currency/currency" enctype="multipart/form-data" id="currency" method="post">
# <a class="block-currency dropdown-toggle" data-toggle="dropdown">
# <!-- <strong></strong> -->
#      USD<span class="caret"></span>
# </a>
# <ul class="dropdown-menu">
# <li><a class="currency-select btn btn-link btn-block" name="EUR">€ Euro</a></li>
# <li><a class="currency-select btn btn-link btn-block" name="GBP">£ Pound Sterling</a></li>
# <li><a class="currency-select btn btn-link btn-block" name="USD">$ US Dollar</a></li>
# </ul>
# <input name="code" type="hidden" value=""/>
# <input name="redirect" type="hidden" value="http://mkw.hk/index.php?route=common/home"/>
# </form>
# </div>
# </div>
# </div><!-- row -->
# </div><!-- container -->
# </div><!-- header-top -->
# </header>
# <nav>
# <div class="header container">
# <div class="row">
# <div class="col-xs-12">
# <div class="mm-toggle-wrap">
# <div class="mm-toggle"> <i class="icon-align-justify"></i><span class="mm-label">Menu</span> </div>
# </div>
# <a class="logo" href="http://mkw.hk/index.php?route=common/home"><img alt="旺角二手機交易網-全港最高手機回收價" class="img-responsive" src="http://mkw.hk/image/catalog/new/logo 2.jpg" title="旺角二手機交易網-全港最高手機回收價"/></a>
# <div class="nav-inner">
# <ul class="hidden-xs" id="nav">
# <li class="level0 nav-5 level-top"><a class="active level-top" href="http://mkw.hk/index.php?route=common/home" id="tab_home"><span>Home</span></a></li>
# <li class="level0 level-top parent">
# <a class="" href="http://mkw.hk/二手手機推薦">
# <span>二手手機推薦</span> </a>
# </li>
# <li class="nav-custom-link level0 level-top parent">
# <a class="level-top" href="https://edigital.top" style="cursor:pointer">二手手機推薦</a>
# </li>
# </ul>
# </div><!-- <div class="nav-inner"> -->
# </div>
# </div>
# </div>
# </nav>
# <style type="text/css">
# #mgkquickview {
#   display: none;
#   background-color: rgba(0, 0, 0, 0.7);
#   width: 95%;
#   height: 1200px;
#   position: fixed;
#   z-index: 9999;
#   top: 0;
#   left: 0;
#   font-family: Verdana, Arial, Helvetica, sans-serif;
#   font-size: 12px;
# }
#   </style><div class="magik-slideshow" id="magik-slideshow">
# <div class="rev_slider_wrapper fullwidthbanner-container" id="rev_slider_4_wrapper">
# <div class="rev_slider fullwidthabanner" id="rev_slider_4">
# <ul>
# <style>#ms0{ cursor: pointer;}</style>
# <script type="text/javascript">
#                     $(document).ready(function(){
#                            $("#ms0").click(function() {
#                                   window.open('https://edigital.top','_blank');
#                            });   });  </script>
# <li data-masterspeed="1000" data-slotamount="7" data-thumb="http://mkw.hk/image/cache/catalog/zhutu-1024x405.jpg" data-transition="random" id="ms0">
# <img data-bgfit="cover" data-bgposition="left top" data-bgrepeat="no-repeat" src="http://mkw.hk/image/cache/catalog/zhutu-1024x405.jpg" title="Slider image 1"/>
# </li>
# </ul>
# </div><!-- rev_slider_4 -->
# </div><!-- rev_slider_4_wrapper -->
# </div>
# </div><!-- page started in header-->
# <script type="text/javascript">
# jQuery(document).ready(function(){
# jQuery('#rev_slider_4').show().revolution({
# dottedOverlay: 'none',
# delay: 5000,
# startwidth: 1920,
# startheight: 680,
#
# hideThumbs: 200,
# thumbWidth: 200,
# thumbHeight: 50,
# thumbAmount: 2,
#
# navigationType: 'thumb',
# navigationArrows: 'solo',
# navigationStyle: 'round',
#
# touchenabled: 'on',
# onHoverStop: 'on',
#
# swipe_velocity: 0.7,
# swipe_min_touches: 1,
# swipe_max_touches: 1,
# drag_block_vertical: false,
#
# spinner: 'spinner0',
# keyboardNavigation: 'off',
#
# navigationHAlign: 'center',
# navigationVAlign: 'bottom',
# navigationHOffset: 0,
# navigationVOffset: 20,
#
# soloArrowLeftHalign: 'left',
# soloArrowLeftValign: 'center',
# soloArrowLeftHOffset: 20,
# soloArrowLeftVOffset: 0,
#
# soloArrowRightHalign: 'right',
# soloArrowRightValign: 'center',
# soloArrowRightHOffset: 20,
# soloArrowRightVOffset: 0,
#
# shadow: 0,
# fullWidth: 'on',
# fullScreen: 'off',
#
# stopLoop: 'off',
# stopAfterLoops: -1,
# stopAtSlide: -1,
#
# shuffle: 'off',
#
# autoHeight: 'off',
# forceFullWidth: 'on',
# fullScreenAlignForce: 'off',
# minFullScreenHeight: 0,
# hideNavDelayOnMobile: 1500,
#
# hideThumbsOnMobile: 'off',
# hideBulletsOnMobile: 'off',
# hideArrowsOnMobile: 'off',
# hideThumbsUnderResolution: 0,
#
# hideSliderAtLimit: 0,
# hideCaptionAtLimit: 0,
# hideAllCaptionAtLilmit: 0,
# startWithSlide: 0,
# fullScreenOffsetContainer: ''
# });
# });
# </script><div>
# <h2>手機回收 手機回收價</h2>
# <table align="center" border="1" style="background-color: rgb(255, 255, 255); font-size: 12px;" width="91%">
# <tbody>
# <tr>
# <td><h3><strong>手機回收網|手機回收|回收手機|手機回收價2022| iphone 13回收價即時| iPhone12回收| iPhone12pro/max回收價| iphone11/11pro/ iPhone 11 pro max回收價| iPhone13回收價 |13pro max回收價| iPhone13pro回收價| iPhone xs回收價| iPhone x回收價| iPhone8/8p回收| iphone7/7p回收價| iPad回收價|iPad mini6回收價|iPad pro回收價| iPad回收價2022| 二手電話回收價| iPhone回收價|二手手機回收價|手機trade |舊手機回收價 macbook回收|Apple watch回收|全新iPhone回收價|回收手提電腦 |買二手手機| 相機回收 airpods回收|全新機回收</strong> </h3>
# </td>
# </tr>
# <tr>
# <td width="1000"> <a href="https://wa.me/message/VDU2CNE4S3MYN1"> <img src="http://mkw.hk/image/catalog/hen2.jpg"/></a></td>
# </tr>
# </tbody>
# </table>
#  <table align="center" border="0" cellpadding="1" cellspacing="1" width="91%">
# <tbody>
# <tr>
# <td bgcolor="#DDF4EA" height="50" width="15%"><h3><strong>手機：</strong></h3>
# </td>
# <td bgcolor="#DDF4EA" height="50" width="75%"><h3><a href="#Apple" style=""><span style="text-decoration-line: underline;">iphone</span> </a>  <a href="#Samsung" style="text-decoration-line: underline;">Samsung</a>    <a href="#Huawei" style="text-decoration-line: underline;">Huawei</a>    <a href="#XIAOMI" style="text-decoration-line: underline;">Xiaomi</a>   </h3>
# </td>
# </tr>
# <tr>
# <td bgcolor="#DDF4EA" height="50"><h3><strong>平板電腦：</strong></h3>
# </td>
# <td bgcolor="#DDF4EA" height="50"><h3><a href="#ipad" style="text-decoration-line: underline;">ipad</a>    <span style="text-decoration-line: underline;"><a href="#Samsung-T"></a></span><a href="#XIAOMI" style="text-decoration-line: underline;">Xiaomi</a></h3>
# </td>
# </tr>
# </tbody>
# </table>
# <table align="center" border="1" cellpadding="0" cellspacing="0" width="91%">
# <tbody>
# <tr height="36">
# <td colspan="3">以下手機 / 平板電腦 回收價只供參考，最新報價請WhatsApp聯絡 (更新於：2022年5月1日)</td>
# </tr>
# <tr height="36">
# <td><h4><strong>Brand</strong></h4>
# </td>
# <td width="1103"><h4><strong>Model</strong></h4>
# </td>
# <td width="169"><h4><strong>回收價</strong></h4>
# </td>
# </tr>
# <tr>
# <td colspan="3"><h4><a id="Apple" name="Apple"><strong>iphone回收價2022</strong></a></h4>
# </td>
# </tr>
# <tr>
# <td bgcolor="#D3F1FE" colspan="3"><h4><strong>iPhone 13回收價 二手回收價（保養期內）</strong></h4>
# </td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 13 128g</h4>
# </td>
# <td>HK$5000</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 13 256g</h4>
# </td>
# <td>HK$5600</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 13 256g</h4>
# </td>
# <td>HK$5950</td>
# </tr>
# <tr>
# <td bgcolor="#D3F1FE" colspan="3"><h4><strong>iPhone 13 pro回收價 二手回收價</strong></h4>
# </td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 13 pro 128GB</h4>
# </td>
# <td>HK$6900</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 13 pro 256GB</h4>
# </td>
# <td>HK$7700</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 13 pro 512GB</h4>
# </td>
# <td>HK$8100</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 13 pro 1T </h4>
# </td>
# <td>HK$8350</td>
# </tr>
# <tr>
# <td bgcolor="#D3F1FE" colspan="3"><h4><strong>iPhone 13 pro max回收價 二手回收價</strong></h4>
# </td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 13 pro max 128GB</h4>
# </td>
# <td>HK$7700</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 13 pro max 256GB</h4>
# </td>
# <td>HK$8700</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 13 pro max 512GB</h4>
# </td>
# <td>HK$9150</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 13 pro max 1T</h4>
# </td>
# <td>HK$9350</td>
# </tr>
# <tr>
# <td bgcolor="#D3F1FE" colspan="3"><h4><strong>iPhone 13 mini 回收價</strong></h4>
# </td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 13 mini 128g</h4>
# </td>
# <td>HK$3700</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 13 mini 256g</h4>
# </td>
# <td>HK$4250</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 13 mini 512g</h4>
# </td>
# <td>HK$5000</td>
# </tr>
# <tr>
# <td bgcolor="#D3F1FE" colspan="3"><h4><strong>iPhone 12 回收價 二手回收價（保養期內）</strong></h4>
# </td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 12 64g</h4>
# </td>
# <td>HK$3250</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 12 128g</h4>
# </td>
# <td>HK$3750</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 12 256g</h4>
# </td>
# <td>HK$4050</td>
# </tr>
# <tr>
# <td bgcolor="#D3F1FE" colspan="3"><h4><strong>iPhone 12 pro回收價 二手回收價</strong></h4>
# </td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 12 pro 128GB</h4>
# </td>
# <td>HK$5100</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 12 pro 256GB</h4>
# </td>
# <td>HK$5500</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 12 pro 512GB</h4>
# </td>
# <td>HK$5750</td>
# </tr>
# <tr>
# <td bgcolor="#D3F1FE" colspan="3"><h4><strong>iPhone 12 pro max回收價 二手回收價</strong></h4>
# </td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 12 pro max 128GB</h4>
# </td>
# <td>HK$5700</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 12 pro max 256GB</h4>
# </td>
# <td>HK$6200</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 12 pro max 512GB</h4>
# </td>
# <td>HK$6450</td>
# </tr>
# <tr>
# <td bgcolor="#D3F1FE" colspan="3"><h4><strong>iPhone 12 mini 回收價</strong></h4>
# </td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 12 mini 64g</h4>
# </td>
# <td>HK$2850</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 12 mini 128g</h4>
# </td>
# <td>HK$3100</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 12 mini 256g</h4>
# </td>
# <td>HK$3450</td>
# </tr>
# <tr>
# <td bgcolor="#D3F1FE" colspan="3"><h4><strong>iPhone se2回收價</strong></h4>
# </td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone se2 64g</h4>
# </td>
# <td>HK$1000</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone se2 128g</h4>
# </td>
# <td>HK$1200</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone se2 256g</h4>
# </td>
# <td>HK$1350</td>
# </tr>
# <tr>
# <td bgcolor="#D3F1FE" colspan="3"><strong></strong><h4><strong>iPhone 11回收價</strong></h4>
# </td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td><h4>iPhone 11 64GB</h4>
# </td>
# <td>HK$2200</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td><h4>iPhone 11 128GB</h4>
# </td>
# <td>HK$2600</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td><h4>iPhone 11 256GB</h4>
# </td>
# <td>HK$2750</td>
# </tr>
# <tr>
# <td bgcolor="#D3F1FE" colspan="3"><strong></strong><h4><strong>iPhone 11 pro 回收價 無需要保養</strong></h4>
# </td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td><h4>iPhone 11 pro 64GB</h4>
# </td>
# <td>HK$2550</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td><h4>iPhone 11 pro 256GB</h4>
# </td>
# <td>HK$3300</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td><h4>iPhone 11 pro 512GB</h4>
# </td>
# <td>HK$3500</td>
# </tr>
# <tr>
# <td bgcolor="#D3F1FE" colspan="3"><strong></strong><h4><strong>iPhone 11 pro max 回收價 無需要保養</strong></h4>
# </td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td><h4>iPhone 11 pro max 64GB</h4>
# </td>
# <td>HK$3400</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td><h4>iPhone 11 pro max 256GB</h4>
# </td>
# <td>HK$4050</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td><h4>iPhone 11 pro max 512GB</h4>
# </td>
# <td>HK$4250</td>
# </tr>
# <tr>
# <td bgcolor="#D3F1FE" colspan="3"><strong></strong><h4><strong>iPhone XS MAX 回收價</strong></h4>
# </td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td><h4>iPhone XS MAX 64GB </h4>
# </td>
# <td>HK$2100</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td><h4>iPhone XS MAX 256GB </h4>
# </td>
# <td>HK$2600</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td><h4>iPhone XS MAX 512GB </h4>
# </td>
# <td>HK$2700</td>
# </tr>
# <tr bgcolor="#D3F1FE" height="20">
# <td colspan="3"><strong></strong><h4><strong>iPhone XS 回收價</strong></h4>
# </td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td><h4>iPhone XS 64GB </h4>
# </td>
# <td>HK$1400</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td><h4>iPhone XS 256GB </h4>
# </td>
# <td>HK$1800</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td><h4>iPhone XS 512GB </h4>
# </td>
# <td>HK$1900</td>
# </tr>
# <tr bgcolor="#D3F1FE" height="20">
# <td colspan="3"><strong></strong><h4><strong>iPhone xr 回收價</strong></h4>
# </td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td><h4>iPhone xr 64GB </h4>
# </td>
# <td>HK$1400</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td><h4>iPhone xr 128GB </h4>
# </td>
# <td>HK$1700</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td><h4>iPhone xr 256GB </h4>
# </td>
# <td>HK$1800</td>
# </tr>
# <tr>
# <td bgcolor="#D3F1FE" colspan="3"><h4><strong>iPhone X回收價</strong></h4>
# </td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone X 64GB </h4>
# </td>
# <td>HK$1250</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone X 256GB </h4>
# </td>
# <td>HK$1500</td>
# </tr>
# <tr>
# <td bgcolor="#D3F1FE" colspan="3"><h4><strong>iPhone 8回收價</strong>  </h4>
# </td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 8 64GB </h4>
# </td>
# <td>HK$650</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 8 256GB </h4>
# </td>
# <td>HK$950</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 8 PLUS 64GB </h4>
# </td>
# <td>HK$1100</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 8 PLUS 256GB </h4>
# </td>
# <td>HK$1350</td>
# </tr>
# <tr>
# <td bgcolor="#D3F1FE" colspan="3"><h4><strong>iPhone 7回收價</strong>  </h4>
# </td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 7 32GB</h4>
# </td>
# <td>HK$400</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 7 128GB </h4>
# </td>
# <td>HK$500</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 7 256GB </h4>
# </td>
# <td>HK$600</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 7 PLUS 回收價 32GB </h4>
# </td>
# <td>HK$600</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 7 PLUS 128GB </h4>
# </td>
# <td>HK$700</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 7 PLUS 256GB </h4>
# </td>
# <td>HK$800</td>
# </tr>
# <tr>
# <td bgcolor="#D3F1FE" colspan="3"><h4><strong>iPhone 6s回收價</strong>  </h4>
# </td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 6s 16GB </h4>
# </td>
# <td>HK$200</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 6s 32GB</h4>
# </td>
# <td>HK$250</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 6s 64GB</h4>
# </td>
# <td>HK$300</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 6s 128GB</h4>
# </td>
# <td>HK$300</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 6s PLUS 16GB</h4>
# </td>
# <td>HK$300</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 6s PLUS 32GB</h4>
# </td>
# <td>HK$350</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 6s PLUS 64GB</h4>
# </td>
# <td>HK$350</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 6s PLUS 128GB</h4>
# </td>
# <td>HK$400</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 6 16GB </h4>
# </td>
# <td>HK$150</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 6 64GB </h4>
# </td>
# <td>HK$200</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 6 128GB</h4>
# </td>
# <td>HK$200</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 6 PLUS 16GB</h4>
# </td>
# <td>HK$200</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 6 PLUS 64GB</h4>
# </td>
# <td>HK$250</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone 6 PLUS 128GB</h4>
# </td>
# <td>HK$250</td>
# </tr>
# <tr>
# <td bgcolor="#D3F1FE" colspan="3"><h4><span style="font-weight: bold;">手機回收</span></h4>
# </td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone SE 16GB</h4>
# </td>
# <td>HK$150</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone SE 32GB</h4>
# </td>
# <td>HK$200</td>
# </tr>
# <tr>
# <td>APPLE</td>
# <td width="1103"><h4>iPhone SE 64GB</h4>
# </td>
# <td>HK$250</td>
# </tr>
# <tr>
# <td> </td>
# <td> </td>
# <td> </td>
# </tr>
# <tr>
# <td bgcolor="#D3F1FE" colspan="3"><h4><a id="Samsung" name="Samsung"><strong>Samsung</strong></a></h4>
# </td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy s21 ultra 回收價 16+512GB</h4>
# </td>
# <td>HK$6800</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy s21 ultra 回收價 12+256GB</h4>
# </td>
# <td>HK$5800</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy s21 plus 回收價 8+256GB</h4>
# </td>
# <td>HK$4600</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy s21回收價 8+256GB</h4>
# </td>
# <td>HK$3300</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy s20 plus 回收價 16+512GB</h4>
# </td>
# <td>HK$2900</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4> Galaxy s20 plus 回收價 12+256GB </h4>
# </td>
# <td>HK$2800</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4> Galaxy s20 plus 回收價 8+128GB </h4>
# </td>
# <td>HK$2600</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy s20回收價8+256GB</h4>
# </td>
# <td>HK$2400</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy s20fe 回收價 128GB</h4>
# </td>
# <td>HK$2200</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy note20 ultra 回收價 512GB </h4>
# </td>
# <td>HK$5000</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy note20 ultra 回收價 256GB</h4>
# </td>
# <td>HK$4500</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4> Galaxy note20 5g 回收價 256GB </h4>
# </td>
# <td>HK$3250</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4> Galaxy fold 3回收價 512GB</h4>
# </td>
# <td>HK$10000</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4> Galaxy fold2回收價512GB </h4>
# </td>
# <td>HK$6200</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4> Galaxy fold 回收價 512GB </h4>
# </td>
# <td>HK$3500</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4> Galaxy z flip3 5G回收價 </h4>
# </td>
# <td>HK$5100</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4> Galaxy z flip 5G回收價 </h4>
# </td>
# <td>HK$3550</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4> Galaxy z flip 4G回收價 </h4>
# </td>
# <td>HK$2550</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td><h4>Galaxy Note 10 256GB </h4>
# </td>
# <td>HK$1750</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td><h4>Galaxy Note 10 plus回收價512GB</h4>
# </td>
# <td>HK$3000</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td><h4>Galaxy Note 10 plus回收價256GB</h4>
# </td>
# <td>HK$2700</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td><h4>Galaxy Note 10 lite回收價</h4>
# </td>
# <td>HK$850</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td><h4>Galaxy S10 回收價(128GB)</h4>
# </td>
# <td>HK$1600</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td><h4>Galaxy S10 (512GB)</h4>
# </td>
# <td>HK$1800</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td><h4>Galaxy S10e 回收價(128GB)</h4>
# </td>
# <td>HK$1300</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td><h4>Galaxy S10 plus (1T)</h4>
# </td>
# <td>HK$2300</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td><h4>Galaxy S10 plus二手回收價 (512GB)</h4>
# </td>
# <td>HK$2000</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td><h4>Galaxy S10 plus (128GB)</h4>
# </td>
# <td>HK$1700</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td><h4>Galaxy Note 9 回收價(128GB)</h4>
# </td>
# <td>HK$1100</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td><h4>Galaxy Note 9二手回收價 (512GB)</h4>
# </td>
# <td>HK$1500</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy Note 8 (64GB)</h4>
# </td>
# <td>HK$650</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy Note 8 (128GB)</h4>
# </td>
# <td>HK$750</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy Note 8 (256GB)</h4>
# </td>
# <td>HK$850</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy S9 回收價(64GB)</h4>
# </td>
# <td>HK$450</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy S9 plus回收價 (64GB)</h4>
# </td>
# <td>HK$650</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy S9 plus(128GB)</h4>
# </td>
# <td>HK$750</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy S9 plus (256GB)</h4>
# </td>
# <td>HK$1100</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy S8</h4>
# </td>
# <td>HK$400</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy S8 plus回收價 64GB</h4>
# </td>
# <td>HK$450</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy S8 plus128GB</h4>
# </td>
# <td>HK$500</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy c9/C9 Pro 64GB</h4>
# </td>
# <td>HK$300</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy C8</h4>
# </td>
# <td>HK$200</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy c7/c7 pro</h4>
# </td>
# <td>HK$200</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy A9 </h4>
# </td>
# <td>HK$200</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy A9 2018年款</h4>
# </td>
# <td>HK$400</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy A80</h4>
# </td>
# <td>HK$800</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy A71 5G版</h4>
# </td>
# <td>HK$1400</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy A70</h4>
# </td>
# <td>HK$600</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy A51回收價</h4>
# </td>
# <td>HK$700</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy A51 5G版回收價</h4>
# </td>
# <td>HK$1050</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy A42回收價</h4>
# </td>
# <td>HK$1100</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy A40s回收價</h4>
# </td>
# <td>HK$400</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy A32回收價</h4>
# </td>
# <td>HK$1000</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy A31回收價</h4>
# </td>
# <td>HK$600</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy A21s回收價</h4>
# </td>
# <td>HK$450</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy A20s回收價</h4>
# </td>
# <td>HK$400</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy S7 (G930F)</h4>
# </td>
# <td>HK$150</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy S7 EDGE (G9350) </h4>
# </td>
# <td>HK$200</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy S6 (G9200)</h4>
# </td>
# <td>HK$100</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy S6 EDGE (G9250) </h4>
# </td>
# <td>HK$150</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy S6 EDGE PLUS (G9287) </h4>
# </td>
# <td>HK$200</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103"><h4>Galaxy Note 5 (N9200)</h4>
# </td>
# <td>HK$350</td>
# </tr>
# <tr>
# <td bgcolor="#D3F1FE" colspan="3"><h4><a id="Huawei" name="Huawei"><strong>Huawei 華爲回收價</strong></a></h4>
# </td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td width="1103"><h4>華為p40 pro 256g</h4>
# </td>
# <td><h4>HK$3300</h4>
# </td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td width="1103"><h4>華為p40 pro+ 512g</h4>
# </td>
# <td><h4>HK$3600</h4>
# </td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td width="1103"><h4>mate8 32GB</h4>
# </td>
# <td><h4>HK$200</h4>
# </td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td width="1103"><h4>mate8 64GB</h4>
# </td>
# <td><h4>HK$200</h4>
# </td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td>mate9 4+32GB</td>
# <td>HK$300</td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td width="1103"><h4>mate9 4+64GB</h4>
# </td>
# <td><h4>HK$300</h4>
# </td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td>mate9 6+128GB</td>
# <td>HK$300</td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td width="1103"><h4>mate9 Pro 4+64GB</h4>
# </td>
# <td><h4>HK$400</h4>
# </td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td><h4>mate9 Pro 6+128GB</h4>
# </td>
# <td>HK$450</td>
# </tr>
# <tr>
# <td>Huawei      </td>
# <td width="1103"><h4>mate10 4+64GB</h4>
# </td>
# <td><h4>HK$550</h4>
# </td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td><h4>mate10 6+128GB</h4>
# </td>
# <td>HK$600</td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td><h4>mate10 PRO 6+64GB</h4>
# </td>
# <td>HK$700</td>
# </tr>
# <tr>
# <td>Huawei      </td>
# <td width="1103"><h4>mate10 PRO 6+128GB</h4>
# </td>
# <td><h4>HK$800</h4>
# </td>
# </tr>
# <tr>
# <td>Huawei      </td>
# <td><h4>mate20 6+64GB</h4>
# </td>
# <td><h4>HK900</h4>
# </td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td><h4>mate20 6+128GB</h4>
# </td>
# <td>HK$1100</td>
# </tr>
# <tr>
# <td>Huawei      </td>
# <td><h4>mate20X 6+128GB</h4>
# </td>
# <td><h4>HK$1150</h4>
# </td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td><h4>mate20X 8+256GB</h4>
# </td>
# <td>HK$1300</td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td><h4>mate20 pro 6+128GB</h4>
# </td>
# <td>HK$1100</td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td><h4>mate20 pro 8+128GB</h4>
# </td>
# <td>HK$1200</td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td><h4>mate20 pro 8+256GB </h4>
# </td>
# <td>HK$1300</td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td><h4>mate30 pro 回收價8+128GB 4G版</h4>
# </td>
# <td>HK$2300</td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td><h4>mate30 pro 8+256GB 4G版</h4>
# </td>
# <td>HK$2600</td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td><h4>mate30 pro 8+128GB 5G版</h4>
# </td>
# <td>HK$3000</td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td><h4>mate30 pro 8+256GB 5G版</h4>
# </td>
# <td>HK$3200</td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td><h4>mate30  6+128GB 4G版</h4>
# </td>
# <td>HK$1300</td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td><h4>mate30  8+128GB 4G版</h4>
# </td>
# <td>HK$1500</td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td><h4>mate30  6+128GB 5G版</h4>
# </td>
# <td>HK$2100</td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td><h4>mate30  8+128GB 5G版</h4>
# </td>
# <td>HK$2500</td>
# </tr>
# <tr>
# <td>Huawei      </td>
# <td width="1103"><h4>P9 32GB/64GB</h4>
# </td>
# <td><h4>HK$200</h4>
# </td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td><h4>P9 plus 4+64GB/128GB</h4>
# </td>
# <td>HK$250</td>
# </tr>
# <tr>
# <td>Huawei      </td>
# <td width="1103"><h4>P10 4+64GB/128GB</h4>
# </td>
# <td><h4>HK$400</h4>
# </td>
# </tr>
# <tr>
# <td>Huawei      </td>
# <td width="1103"><h4>P10 Plus 6+128GB/256GB</h4>
# </td>
# <td><h4>HK$400</h4>
# </td>
# </tr>
# <tr>
# <td>Huawei      </td>
# <td width="1103"><h4>P20 6+64GB</h4>
# </td>
# <td><h4>HK$550</h4>
# </td>
# </tr>
# <tr>
# <td>Huawei      </td>
# <td width="1103"><h4>P20 6+128GB</h4>
# </td>
# <td><h4>HK$600</h4>
# </td>
# </tr>
# <tr>
# <td>Huawei      </td>
# <td width="1103"><h4>P20 PRO 6+64GB/128GB</h4>
# </td>
# <td><h4>HK$650</h4>
# </td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td><h4>P20 PRO 6+256GB/8+128GB</h4>
# </td>
# <td>HK$850</td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td><h4>P20 PRO/8+256GB</h4>
# </td>
# <td>HK$950</td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td><h4>P30 6+128GB/8+128GB </h4>
# </td>
# <td>HK$1200</td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td><h4>P30 8+256GB</h4>
# </td>
# <td>HK$1500</td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td><h4>P30 pro 8+128GB</h4>
# </td>
# <td>HK$1500</td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td><h4>P30 pro 8+256GB</h4>
# </td>
# <td>HK$1700</td>
# </tr>
# <tr>
# <td>Huawei</td>
# <td><h4>P30 pro 8+512GB</h4>
# </td>
# <td>HK$2000</td>
# </tr>
# <tr>
# <td>Huawei      </td>
# <td width="1103"><h4>NOVA 9 pro  8+128GB</h4>
# </td>
# <td><h4>HK$2200</h4>
# </td>
# </tr>
# <tr>
# <td>Huawei      </td>
# <td width="1103"><h4>NOVA 9 pro  8+256GB</h4>
# </td>
# <td><h4>HK$2700</h4>
# </td>
# </tr>
# <tr>
# <td>Huawei      </td>
# <td width="1103"><h4>NOVA 9  8+128GB</h4>
# </td>
# <td><h4>HK$2000</h4>
# </td>
# </tr>
# <tr>
# <td>Huawei      </td>
# <td width="1103"><h4>NOVA 9  8+256GB</h4>
# </td>
# <td><h4>HK$2200</h4>
# </td>
# </tr>
# <tr>
# <td>Huawei      </td>
# <td width="1103"><h4>NOVA 8 5G版 8+128GB</h4>
# </td>
# <td><h4>HK$2000</h4>
# </td>
# </tr>
# <tr>
# <td>Huawei      </td>
# <td width="1103"><h4>NOVA 8 5G版 8+256GB</h4>
# </td>
# <td><h4>HK$2300</h4>
# </td>
# </tr>
# <tr>
# <td>Huawei      </td>
# <td width="1103"><h4>NOVA 8 pro 5G版 8+128GB</h4>
# </td>
# <td><h4>HK$2350</h4>
# </td>
# </tr>
# <tr>
# <td>Huawei      </td>
# <td width="1103"><h4>NOVA 8 pro 5G版 8+256GB</h4>
# </td>
# <td><h4>HK$2750</h4>
# </td>
# </tr>
# <tr>
# <td>Huawei      </td>
# <td width="1103"><h4>Huawei MEDIA PAD M3 LITE 8 INCH LTE</h4>
# </td>
# <td><h4>HK$500</h4>
# </td>
# </tr>
# <tr>
# <td>Huawei      </td>
# <td width="1103"><h4>Huawei MEDIA PAD M5 8.4 INCH LTE</h4>
# </td>
# <td><h4>HK$900</h4>
# </td>
# </tr>
# <tr>
# <td><h4> </h4>
# </td>
# <td width="1103"><h4> </h4>
# </td>
# <td><h4> </h4>
# </td>
# </tr>
# <tr>
# <td bgcolor="#D3F1FE" colspan="3"><h4><a id="ipad" name="ipad"><strong>ipad回收/iPad回收價</strong></a></h4>
# </td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 12.9吋 第四代 （2020款）回收價wifi 128GB (4G+HK$350)</h4>
# </td>
# <td>HK$5500</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 12.9吋 第四代 （2020款）回收價wifi 256GB (4G+HK$350)</h4>
# </td>
# <td>HK$5900</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 12.9吋 第四代 （2020款）回收價wifi 512GB (4G+HK$350)</h4>
# </td>
# <td>HK6200</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 12.9吋 第四代 （2020款）回收價wifi 1T (4G+HK$350)</h4>
# </td>
# <td>HK$6400</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 12.9吋 第三代 （2018款）回收價wifi 64GB (4G+HK$300)</h4>
# </td>
# <td>HK$3500</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 12.9吋 第三代 （2018款） wifi 256GB (4G+HK$300)</h4>
# </td>
# <td>HK$4000</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 12.9吋 第三代（2018款）wifi 512GB(4G+HK$300)</h4>
# </td>
# <td>HK$4600</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 11吋（2020款）第二代 回收價wifi 128GB (4G+HK$350)</h4>
# </td>
# <td>HK$4200</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 11吋（2020款）第二代 回收價wifi 256GB (4G+HK$350)</h4>
# </td>
# <td>HK$4900</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 11吋（2020款）第二代 回收價wifi 512GB (4G+HK$350)</h4>
# </td>
# <td>HK$5200</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 11吋（2020款）第二代 回收價wifi 1T (4G+HK$300)</h4>
# </td>
# <td>HK$5500</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 11吋（2018款）第一代 回收價wifi 64GB (4G+HK$350)</h4>
# </td>
# <td>HK$3300</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 11吋（2018款）第一代 回收價wifi 256GB (4G+HK$350)</h4>
# </td>
# <td>HK$3850</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 11吋（2018款）第一代 回收價wifi 512GB (4G+HK$350)</h4>
# </td>
# <td>HK$4150</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 11吋（2018款）第一代 回收價wifi 1T (4G+HK$300)</h4>
# </td>
# <td>HK$4350</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 12.9吋 第二代 （2017款）wifi 64GB (4G+HK$300)</h4>
# </td>
# <td>HK$2150</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 12.9吋 第二代（2017款）wifi 256GB (4G+HK$300)</h4>
# </td>
# <td>HK$2600</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 12.9吋 第二代（2017款）wifi 512GB (4G+HK$350)</h4>
# </td>
# <td>HK$3000</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 10.5吋 第二代（2017款）wifi 64GB (4G+HK$250)</h4>
# </td>
# <td>HK$1600</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 10.5吋 第二代 （2017款）wifi 256GB (4G+HK$250)</h4>
# </td>
# <td>HK$2100</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 10.5吋 第二代（2017款）wifi 512GB (4G+HK$250)</h4>
# </td>
# <td>HK$2400</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 12.9吋 第一代（2015款） wifi 32GB (4G+HK$200)</h4>
# </td>
# <td>HK$1550</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 12.9吋 第一代（2015款） wifi 128GB (4G+HK$200)</h4>
# </td>
# <td>HK$1900</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 12.9吋 第一代（2015款） wifi 256GB (4G+HK$200)</h4>
# </td>
# <td>HK$2200</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 9.7inch 第一代（2016款）wifi 32GB (4G+HK$200)</h4>
# </td>
# <td>HK$1100</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 9.7inch 第一代（2016款）wifi 128GB (4G+HK$200)</h4>
# </td>
# <td>HK$1300</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad pro 9.7inch 第一代（2016款）wifi 256GB (4G+HK$200)</h4>
# </td>
# <td>HK$1500</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td><h4>iPad air4 wifi 64GB (4G+HK$300)</h4>
# </td>
# <td>HK$3400</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td><h4>iPad air4 wifi 256GB (4G+HK$300)</h4>
# </td>
# <td>HK$4000</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td><h4>iPad air3 wifi 回收價64GB (4G+HK$250)</h4>
# </td>
# <td>HK$2200</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td><h4>iPad air3 wifi 256GB (4G+HK$250)</h4>
# </td>
# <td>HK$2800</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad air2 回收價wifi 16GB (4G+HK$200)</h4>
# </td>
# <td>HK$650</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad air2 wifi 64GB (4G+HK$200)</h4>
# </td>
# <td>HK$850</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad air2 wifi 128GB (4G+HK$200)</h4>
# </td>
# <td>HK$1050</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad air回收價 wifi16GB (3G+HK$100)</h4>
# </td>
# <td>HK$350</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad air wifi32GB (3G+HK$100)</h4>
# </td>
# <td>HK$450</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad air wifi64GB (3G+HK$100)</h4>
# </td>
# <td>HK$550</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td><h4>iPad 8回收價（2020） wifi32GB (3G+HK$300)</h4>
# </td>
# <td>HK$1700</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td><h4>iPad 8（2020） wifi128GB (3G+HK$300)</h4>
# </td>
# <td>HK$2200</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td><h4>iPad 7回收價（2019） wifi32GB (3G+HK$250)</h4>
# </td>
# <td>HK$1400</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td><h4>iPad 7（2019） wifi128GB (3G+HK$250)</h4>
# </td>
# <td>HK$1800</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td><h4>iPad 6（2018） wifi32GB (3G+HK$200)</h4>
# </td>
# <td>HK$1100</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td><h4>iPad 6（2018） wifi128GB (3G+HK$200)</h4>
# </td>
# <td>HK$1400</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad 5（2017） wifi32GB (3G+HK$200)</h4>
# </td>
# <td>HK$900</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad 5（2017） wifi128GB (3G+HK$200)</h4>
# </td>
# <td>HK$1150</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad mini5回收價 wifi 64GB (4G+HK$450)</h4>
# </td>
# <td>HK$1700</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad mini5 wifi 256GB (4G+HK$450)</h4>
# </td>
# <td>HK$2200</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad mini4 wifi16GB (4G+HK$200)</h4>
# </td>
# <td>HK$700</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad mini4 wifi64GB (4G+HK$200)</h4>
# </td>
# <td>HK$950</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad mini4 wifi128GB (4G+HK$200)</h4>
# </td>
# <td>HK$1100</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad mini3 wifi16GB (4G+HK$100)</h4>
# </td>
# <td>HK$400</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad mini3 wifi64GB (4G+HK$100)</h4>
# </td>
# <td>HK$550</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad mini3 wifi128GB (4G+HK$100)</h4>
# </td>
# <td>HK$650</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad mini2 wifi16GB (3G+HK$50)</h4>
# </td>
# <td>HK$300</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad mini2 wifi32GB (3G+HK$50)</h4>
# </td>
# <td>HK$400</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad mini2 wifi64GB (3G+HK$50)</h4>
# </td>
# <td>HK$500</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad mini2 wifi128GB (3G+HK$50)</h4>
# </td>
# <td>HK$550</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad mini 1 wifi16GB (3G+HK$50)</h4>
# </td>
# <td>HK$100</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad mini 1 wifi32GB (3G+HK$50)</h4>
# </td>
# <td>HK$150</td>
# </tr>
# <tr>
# <td>Apple</td>
# <td width="1103"><h4>iPad mini 1 wifi64GB (3G+HK$50)</h4>
# </td>
# <td>HK$150</td>
# </tr>
# <tr>
# <td><h4> </h4>
# </td>
# <td width="1103"><h4> </h4>
# </td>
# <td><h4> </h4>
# </td>
# </tr>
# <tr>
# <td bgcolor="#D3F1FE" colspan="3"><h4><a id="Samsung-T" name="Samsung-T"><strong>Samsung</strong></a></h4>
# </td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103">Galaxy Tab S 8.4 (T700 - wifi)</td>
# <td>HK$500</td>
# </tr>
# <tr>
# <td>Samsung</td>
# <td width="1103">Galaxy Tab S 8.4 (T705 - 4G)</td>
# <td>HK$600</td>
# </tr>
# <tr>
# <td bgcolor="#D3F1FE" colspan="3"><h4><a id="XIAOMI" name="XIAOMI"><strong>Xiaomi</strong></a></h4>
# </td>
# </tr>
# <tr>
# <td>Xiaomi</td>
# <td width="1103"> <h4>小米 11 pro (8+128GB) （8+256GB/+HK$300）（12+256GB/+HK$500）</h4>
# </td>
# <td>HK$3800</td>
# </tr>
# <tr>
# <td>Xiaomi</td>
# <td width="1103"> <h4>小米 11 (8+128GB) （8+256GB/+HK$300）（12+256GB/+HK$500）</h4>
# </td>
# <td>HK$2800</td>
# </tr>
# <tr>
# <td>Xiaomi</td>
# <td width="1103"> <h4>小米 10 pro (8+256GB) （12+256GB/+HK$250）（12+512GB/+HK$500）</h4>
# </td>
# <td>HK$2350</td>
# </tr>
# <tr>
# <td>Xiaomi</td>
# <td width="1103"> <h4>小米 10 (8+128GB) （8+256GB/+HK$200）（12+256GB/+HK$400）</h4>
# </td>
# <td>HK$1800</td>
# </tr>
# <tr>
# <td>Xiaomi</td>
# <td width="1103"> <h4>小米 10T pro (8+256GB)</h4>
# </td>
# <td>HK$2000</td>
# </tr>
# <tr>
# <td>Xiaomi</td>
# <td width="1103"> <h4>小米 9pro (8+128GB) （8+256GB/+HK$200）（12+256GB/+HK$400）</h4>
# </td>
# <td>HK$1400</td>
# </tr>
# <tr>
# <td>Xiaomi</td>
# <td width="1103"><h4>小米9  (6+128GB) （8+128GB/+HK$100）（8+256GB/+HK$300）</h4>
# </td>
# <td>HK$1000</td>
# </tr>
# <tr>
# <td>Xiaomi</td>
# <td width="1103"><h4>小米10 lite (6+128GB) （8+128GB/+HK$150）（8+256GB/+HK$300)</h4>
# </td>
# <td>HK$850</td>
# </tr>
# </tbody>
# </table></div>
# <footer class="">
# <div class="footer-middle">
# <div class="container">
# <div class="row">
# <div class="col-md-2 col-sm-4">
# <h4>會員服務</h4>
# <ul class="links">
# <li class="first"><a href="http://mkw.hk/index.php?route=information/contact">聯系我們</a></li>
# <li><a href="http://mkw.hk/index.php?route=account/return/add">退換服務</a></li>
# <li><a href="http://mkw.hk/index.php?route=account/order">曆史訂單</a></li>
# <li><a href="http://mkw.hk/index.php?route=account/wishlist">收藏列表</a></li>
# <li><a href="http://mkw.hk/index.php?route=information/sitemap">網站地圖</a></li>
# <li class="last"><a href="http://mkw.hk/index.php?route=account/account" title="會員中心">會員中心</a></li>
# </ul>
# </div>
# <div class="col-md-2 col-sm-4">
# <h4>其他</h4>
# <ul class="links">
# <li class="first"><a href="http://mkw.hk/index.php?route=product/manufacturer">品牌專區</a></li>
# <li><a href="http://mkw.hk/index.php?route=account/voucher">禮品券</a></li>
# <li><a href="http://mkw.hk/index.php?route=affiliate/account">推广會員</a></li>
# <li><a href="http://mkw.hk/index.php?route=account/wishlist">收藏列表</a></li>
# <li><a href="http://mkw.hk/index.php?route=account/order">曆史訂單</a></li>
# <li class="last"><a href="http://mkw.hk/index.php?route=product/special">優惠商品</a></li>
# </ul>
# </div>
# <div class="col-md-3 col-sm-4">
# <h4>Contact Us</h4>
# <div class="contacts-info">
# <div class="phone-footer">
# <i class="phone-icon"> </i>
#                 +852 59139457‬              </div>
# <div class="email-footer">
# <i class="email-icon"> </i>
# <a href="#">mkw@gmail.com</a>
# </div>
# </div>
# </div>
# </div><!-- row -->
# </div>
# </div><!-- footer-middle -->
# <div class="footer-top">
# <div class="container">
# <div class="row">
# <div class="col-xs-12 col-sm-6">
# <div class="payment-accept">
# <img alt="payment1" src="catalog/view/theme/micra/image/payment-1.png"/>
# <img alt="payment2" src="catalog/view/theme/micra/image/payment-2.png"/>
# <img alt="payment3" src="catalog/view/theme/micra/image/payment-3.png"/>
# <img alt="payment4" src="catalog/view/theme/micra/image/payment-4.png"/>
# </div>
# </div>
# <div class="col-xs-12 col-sm-6">
# <div class="social">
# <ul>
# <li class="fb"><a href="https://www.facebook.com/mkw88" target="_blank"></a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="footer-bottom">
# <div class="container">
# <div class="row">
# <h5><span style="color: rgb(206, 198, 206); background-color: rgb(0, 0, 0);"> © 2012-2021 MKW旺角二手網. All Rights Reserved. </span></h5>
# </div>
# </div>
# </div>
# <div id="mgkquickview">
# <div id="magikloading" style="display:none;text-align:center;margin-top:400px;"><img alt="loading" src="catalog/view/theme/micra/image/loading.gif"/>
# </div></div>
# </footer>
# <div id="mobile-menu">
# <ul>
# <li>
# <div class="home"><a class="active" href="http://mkw.hk/index.php?route=common/home"><i class="icon-home"></i>Home</a></div>
# </li>
# <li><a href="http://mkw.hk/二手手機推薦">二手手機推薦</a>
# </li>
# </ul>
# </div><!-- mobile-menu -->
# <script type="text/javascript">
# var isTouchDevice = ('ontouchstart' in window) || (navigator.msMaxTouchPoints > 0);
# jQuery(window).on("load", function() {
#
# if (isTouchDevice)
# {
# jQuery('#nav a.level-top').click(function(e) {
# $t = jQuery(this);
# $parent = $t.parent();
# if ($parent.hasClass('parent'))
# {
# if ( !$t.hasClass('menu-ready'))
# {
# jQuery('#nav a.level-top').removeClass('menu-ready');
# $t.addClass('menu-ready');
# return false;
# }
# else
# {
# $t.removeClass('menu-ready');
# }
# }
# });
# }
# //on load
# jQuery().UItoTop();
#
#
# }); //end: on load
#
# //]]>
#
#
# /*--------| UItoTop jQuery Plugin 1.1-------------------*/
# (function($){
# jQuery.fn.UItoTop = function(options) {
#
# var defaults = {
# text: '',
# min: 200,
# inDelay:600,
# outDelay:400,
# containerID: 'toTop',
# containerHoverID: 'toTopHover',
# scrollSpeed: 1200,
# easingType: 'linear'
# };
#
# var settings = $.extend(defaults, options);
# var containerIDhash = '#' + settings.containerID;
# var containerHoverIDHash = '#'+settings.containerHoverID;
#
# jQuery('body').append('<a href="#" id="'+settings.containerID+'">'+settings.text+'</a>');
# jQuery(containerIDhash).hide().click(function(){
# jQuery('html, body').animate({scrollTop:0}, settings.scrollSpeed, settings.easingType);
# jQuery('#'+settings.containerHoverID, this).stop().animate({'opacity': 0 }, settings.inDelay, settings.easingType);
# return false;
# })
# .prepend('<span id="'+settings.containerHoverID+'"></span>')
# .hover(function() {
# jQuery(containerHoverIDHash, this).stop().animate({
# 'opacity': 1
# }, 600, 'linear');
# }, function() {
# jQuery(containerHoverIDHash, this).stop().animate({
# 'opacity': 0
# }, 700, 'linear');
# });
#
# jQuery(window).scroll(function() {
# var sd = $(window).scrollTop();
# if(typeof document.body.style.maxHeight === "undefined") {
# jQuery(containerIDhash).css({
# 'position': 'absolute',
# 'top': $(window).scrollTop() + $(window).height() - 50
# });
# }
# if ( sd > settings.min )
# jQuery(containerIDhash).fadeIn(settings.inDelay);
# else
# jQuery(containerIDhash).fadeOut(settings.Outdelay);
# });
#
# };
# })(jQuery);
#
#
# /*--------| End UItoTop -------------------*/
# </script>
# <!--
# OpenCart is open source software and you are free to remove the powered by OpenCart if you want, but its generally accepted practise to make a small donation.
# Please donate via PayPal to donate@opencart.com
# //-->
# <!-- Theme created by Welford Media for OpenCart 2.0 www.welfordmedia.co.uk -->
# </body></html>

# %%
yy = re.findall('\d+\年', str(soup)) 
mm = re.findall('\d+\月', str(soup)) 
dd = re.findall('\d+\日', str(soup)) 

dated = '-'.join([yy[0][:-1],mm[0][:-1],dd[0][:-1]])
dated = datetime.datetime.strptime(dated, '%Y-%m-%d')
print(dated)
# Out:
# 2022-05-01 00:00:00

# %%
brand, model, price, date = [], [], [], []

for rows in soup.find_all('tr')[7:]:
    #print(rows)
    try: 
        columns = rows.find_all('td')
        brand.append(columns[0].text.replace('\n',''))
        model.append(columns[1].text.replace('\n',''))
        price.append(columns[2].text.replace('HK$','').replace('HK',''))  
        date.append(dated)
       
    except: model.append(0) or price.append(0) or date.append(0)
        
print(len(brand),len(model),len(price), len(date))
# Out:
# 288 288 288 288

# %%
MK = pd.DataFrame({'Brand':brand, 'Model':model, 'Price':price, 'Date':date})

# %%
MK = MK[MK.Price != 0]

# %%
MK.head()  # can use Regex to filter models
# Out:
#    Brand                Model Price                 Date
# 1  APPLE       iPhone 13 128g  5000  2022-05-01 00:00:00
# 2  APPLE       iPhone 13 256g  5600  2022-05-01 00:00:00
# 3  APPLE       iPhone 13 256g  5950  2022-05-01 00:00:00
# 5  APPLE  iPhone 13 pro 128GB  6900  2022-05-01 00:00:00
# 6  APPLE  iPhone 13 pro 256GB  7700  2022-05-01 00:00:00

# %% [markdown]
# ### Scraping via Web Archive
# #### Multiple periods

# %%
# Historical prices to be scraped from Wayback Archive using its API to find relevant dates
# https://archive.org/help/wayback_api.php

# %%
# define scraping period
dateRange = pd.Series(pd.bdate_range(start='2019-09-30', end='2022-05-03', freq='M')).dt.strftime('%Y%m%d')

# %%
# Using Web Archive API to identify available URLs to be plugged into Beautiful Soup

target = 'http://archive.org/wayback/available?url=http://www.mkw.hk/&timestamp='
headers = {"Accept": "application/json"}
URL_list = []

for date in dateRange:
    try:
        res =requests.get(''.join([target,date]), headers=headers )
        #print(res)
        d = json.loads(res.text)
        URL_list.append(d['archived_snapshots']['closest']['url'])
    except: pass

URL_list  # all links to be scraped
# Out:
# ['http://web.archive.org/web/20190924052348/http://mkw.hk:80/',
#  'http://web.archive.org/web/20191022175922/http://mkw.hk:80/',
#  'http://web.archive.org/web/20191122141143/http://mkw.hk:80/',
#  'http://web.archive.org/web/20200109222027/http://www.mkw.hk:80/',
#  'http://web.archive.org/web/20200209045102/http://www.mkw.hk:80/',
#  'http://web.archive.org/web/20200221025946/http://mkw.hk:80/',
#  'http://web.archive.org/web/20200322063612/http://www.mkw.hk:80/',
#  'http://web.archive.org/web/20200429115058/http://mkw.hk:80/',
#  'http://web.archive.org/web/20200529174855/http://mkw.hk:80/',
#  'http://web.archive.org/web/20200629001159/http://mkw.hk:80/',
#  'http://web.archive.org/web/20200729052547/http://mkw.hk:80/',
#  'http://web.archive.org/web/20200919190139/http://mkw.hk/',
#  'http://web.archive.org/web/20200919190139/http://mkw.hk/',
#  'http://web.archive.org/web/20201031223605/http://mkw.hk/',
#  'http://web.archive.org/web/20201127033029/http://mkw.hk/',
#  'http://web.archive.org/web/20210116060815/http://mkw.hk/',
#  'http://web.archive.org/web/20210116060815/http://mkw.hk/',
#  'http://web.archive.org/web/20210228005213/http://mkw.hk/',
#  'http://web.archive.org/web/20210417180129/http://mkw.hk/',
#  'http://web.archive.org/web/20210511012747/http://mkw.hk/',
#  'http://web.archive.org/web/20210613024658/http://mkw.hk/',
#  'http://web.archive.org/web/20210613024658/http://mkw.hk/',
#  'http://web.archive.org/web/20210613024658/http://mkw.hk/',
#  'http://web.archive.org/web/20210613024658/http://mkw.hk/',
#  'http://web.archive.org/web/20211218023728/http://mkw.hk/',
#  'http://web.archive.org/web/20211218023728/http://mkw.hk/',
#  'http://web.archive.org/web/20211218023728/http://mkw.hk/',
#  'http://web.archive.org/web/20211218023728/http://mkw.hk/',
#  'http://web.archive.org/web/20211218023728/http://mkw.hk/',
#  'http://web.archive.org/web/20220419031715/http://mkw.hk/',
#  'http://web.archive.org/web/20220419031715/http://mkw.hk/',
#  'http://web.archive.org/web/20220419032515/http://www.mkw.hk/']

# %%
# Execute Beautiful Soup and transfer to pandas DF

brandMaster, modelMaster, priceMaster, dateMaster = [], [], [], []

for URL in URL_list:
    html = requests.get(URL)
    URL_source_code=html.text
    soup=BeautifulSoup(URL_source_code,"html.parser")

    # Date finder
    yy = re.findall('\d+\年', str(soup)) 
    mm = re.findall('\d+\月', str(soup)) 
    dd = re.findall('\d+\日', str(soup)) 

    dated = '-'.join([yy[0][:-1],mm[0][:-1],dd[0][:-1]])
    dated = datetime.datetime.strptime(dated, '%Y-%m-%d')

    # Scrape and build price and model dataset
    brand, model, price, date = [], [], [], []

    for rows in soup.find_all('tr')[7:]:
        try: 
            columns = rows.find_all('td')
            brand.append(columns[0].text.replace('\n',''))
            model.append(columns[1].text.replace('\n',''))
            price.append(columns[2].text.replace('HK$','').replace('HK','').replace('\n',''))
            date.append(dated)
        except: model.append(0) or price.append(0) or date.append(0)  # for single-column rows
    
    brandMaster.extend(brand)
    modelMaster.extend(model)
    priceMaster.extend(price)
    dateMaster.extend(date)
    #print(len(brand),len(model),len(price), len(date))  # check dataset is complete 

MKW = pd.DataFrame({'Brand':brandMaster, 'Model':modelMaster, 'Price':priceMaster, 'Date':dateMaster})

# Clean up blank space values (https://stackoverflow.com/questions/13445241/replacing-blank-values-white-space-with-nan-in-pandas)
for i in MKW.columns:
    MKW[i][MKW[i].apply(lambda i: True if re.search('^\s*$', str(i)) else False)]=0

MKW = MKW[MKW.Price != 0]  # strip out non pricing data

# %%
MKW.info(), MKW.head()  # scraped results
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7954 entries, 1 to 8740
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Brand   7954 non-null   object
#  1   Model   7954 non-null   object
#  2   Price   7954 non-null   object
#  3   Date    7954 non-null   object
# dtypes: object(4)
# memory usage: 310.7+ KB
# (None,
#     Brand                     Model Price                 Date
#  1  APPLE  iPhone 5 16GB/32GB/64GB     50  2019-09-08 00:00:00
#  3  APPLE            iPhone 5s 16GB   100  2019-09-08 00:00:00
#  4  APPLE      iPhone 5s 32GB 64GB    150  2019-09-08 00:00:00
#  6  APPLE           iPhone 5c 16GB    100  2019-09-08 00:00:00
#  7  APPLE            iPhone 5c 32GB   100  2019-09-08 00:00:00)

# %%
# Remove duplicates since some of data scraped from archived pages of same day (diff time)
print('Duplicated rows:',MKW.duplicated().sum())
MKW.drop_duplicates(inplace=True)
print('Post removing duplicates (rows, cols):',MKW.shape)
# Out:
# Duplicated rows: 5272
# Post removing duplicates (rows, cols): (2682, 4)

# %%
MKW.reset_index(inplace=True)
MKW = MKW.iloc[:,1:]

# %%
MKW.head()
# Out:
#    Brand                     Model Price                 Date
# 0  APPLE  iPhone 5 16GB/32GB/64GB     50  2019-09-08 00:00:00
# 1  APPLE            iPhone 5s 16GB   100  2019-09-08 00:00:00
# 2  APPLE      iPhone 5s 32GB 64GB    150  2019-09-08 00:00:00
# 3  APPLE           iPhone 5c 16GB    100  2019-09-08 00:00:00
# 4  APPLE            iPhone 5c 32GB   100  2019-09-08 00:00:00

# %%
MKW.to_csv('supplier_px.csv')  # export
